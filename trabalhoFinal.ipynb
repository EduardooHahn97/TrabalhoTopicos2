# %% [markdown]
# # Grupo:
# # Eduardo Vinicius Hahn
# # Leandro Seiti Kakimoto
# # Lucas Felippe Mateus

# %%
#importando as bibliotecas nescessárias para o desenvolvimento do trabalho
import numpy as np
import pandas as pd

# %%
#Carregando o data set -> resultados de partidas de CS:Go Professional Matches
resultados = pd.read_csv('results.csv')

#Exibindo os dez primeiros registros do data set
#resultados.head(10)
resultados
# Out:
#              date               team_1          team_2         _map  result_1  \
# 0      2020-03-18              Recon 5         TeamOne        Dust2         0
# 1      2020-03-18              Recon 5         TeamOne      Inferno        13
# 2      2020-03-18  New England Whalers        Station7      Inferno        12
# 3      2020-03-18              Rugratz  Bad News Bears      Inferno         7
# 4      2020-03-18              Rugratz  Bad News Bears      Vertigo         8
# ...           ...                  ...             ...          ...       ...
# 45768  2015-11-05                   G2      E-frag.net      Inferno        13
# 45769  2015-11-05                   G2      E-frag.net        Dust2        16
# 45770  2015-11-04                  CLG          Liquid      Inferno        16
# 45771  2015-11-03                  NiP        Dignitas        Train        16
# 45772  2015-11-03                  NiP            Envy  Cobblestone        16
#
# ...

# %%
# Verificando quantos registros existem no data set
# O método count() retorna a quantia de ocorrências não nulas em linhas ou colunas.
# O parâmetro axis=0 indica que as linhas estão consideradas na contagem, enquando que level=None indica que a contagem
# não se dá por níveis (no caso de uma indexação hierarquica) e numeric_only = False indica que qualquer tipo de dado entra
# na contagem (não somente os numéricos).
resultados.count(axis=0, level=None, numeric_only=False)
# Out:
# date            45773
# team_1          45773
# team_2          45773
# _map            45773
# result_1        45773
# result_2        45773
# map_winner      45773
# starting_ct     45773
# ct_1            45773
# t_2             45773
# t_1             45773
# ct_2            45773
# event_id        45773
# match_id        45773
# rank_1          45773
# rank_2          45773
# map_wins_1      45773
# map_wins_2      45773
# match_winner    45773
# dtype: int64

# %%
#verificando se há algum dado ausente no data set
resultados.isnull()
# Out:
#         date  team_1  team_2   _map  result_1  result_2  map_winner  \
# 0      False   False   False  False     False     False       False
# 1      False   False   False  False     False     False       False
# 2      False   False   False  False     False     False       False
# 3      False   False   False  False     False     False       False
# 4      False   False   False  False     False     False       False
# ...      ...     ...     ...    ...       ...       ...         ...
# 45768  False   False   False  False     False     False       False
# 45769  False   False   False  False     False     False       False
# 45770  False   False   False  False     False     False       False
# 45771  False   False   False  False     False     False       False
# 45772  False   False   False  False     False     False       False
#
#        starting_ct   ct_1    t_2    t_1   ct_2  event_id  match_id  rank_1  \
# ...

# %%
#filtrando dados ausentes
resultados.dropna()
# Out:
#              date               team_1          team_2         _map  result_1  \
# 0      2020-03-18              Recon 5         TeamOne        Dust2         0
# 1      2020-03-18              Recon 5         TeamOne      Inferno        13
# 2      2020-03-18  New England Whalers        Station7      Inferno        12
# 3      2020-03-18              Rugratz  Bad News Bears      Inferno         7
# 4      2020-03-18              Rugratz  Bad News Bears      Vertigo         8
# ...           ...                  ...             ...          ...       ...
# 45768  2015-11-05                   G2      E-frag.net      Inferno        13
# 45769  2015-11-05                   G2      E-frag.net        Dust2        16
# 45770  2015-11-04                  CLG          Liquid      Inferno        16
# 45771  2015-11-03                  NiP        Dignitas        Train        16
# 45772  2015-11-03                  NiP            Envy  Cobblestone        16
#
# ...

# %%
#Verificando se há algum registro duplicado no data set
resultados.drop_duplicates()
# Out:
#              date               team_1          team_2         _map  result_1  \
# 0      2020-03-18              Recon 5         TeamOne        Dust2         0
# 1      2020-03-18              Recon 5         TeamOne      Inferno        13
# 2      2020-03-18  New England Whalers        Station7      Inferno        12
# 3      2020-03-18              Rugratz  Bad News Bears      Inferno         7
# 4      2020-03-18              Rugratz  Bad News Bears      Vertigo         8
# ...           ...                  ...             ...          ...       ...
# 45768  2015-11-05                   G2      E-frag.net      Inferno        13
# 45769  2015-11-05                   G2      E-frag.net        Dust2        16
# 45770  2015-11-04                  CLG          Liquid      Inferno        16
# 45771  2015-11-03                  NiP        Dignitas        Train        16
# 45772  2015-11-03                  NiP            Envy  Cobblestone        16
#
# ...

# %%
#Renomeando o nome dos atributos vizando torna-los mais intuitivos
resultados = resultados.rename(columns={'ct_1': 'Pontuação como Antiterrorista - Time 1'})
resultados = resultados.rename(columns={'t_2': 'Pontuação como Terrorista - Time 2'})
resultados = resultados.rename(columns={'ct_2': 'Pontuação como Antiterrorista - Time 2'})
resultados = resultados.rename(columns={'t_1': 'Pontuação como Terrorista - Time 1'})
resultados = resultados.rename(columns={'starting_ct': 'Time que iniciou como Antiterrorista'})

#Exibindo os dez primeiros registros do data set após renomear determinados atributos
resultados.head(20)
# Out:
#           date                team_1           team_2      _map  result_1  \
# 0   2020-03-18               Recon 5          TeamOne     Dust2         0
# 1   2020-03-18               Recon 5          TeamOne   Inferno        13
# 2   2020-03-18   New England Whalers         Station7   Inferno        12
# 3   2020-03-18               Rugratz   Bad News Bears   Inferno         7
# 4   2020-03-18               Rugratz   Bad News Bears   Vertigo         8
# 5   2020-03-17           Singularity         Endpoint  Overpass        13
# 6   2020-03-17           Singularity         Endpoint   Vertigo        11
# 7   2020-03-17                Espada          Tricked     Dust2        16
# 8   2020-03-17                Espada          Tricked      Nuke        16
# 9   2020-03-17                fnatic              BIG    Mirage        12
# 10  2020-03-17                Sprout  Movistar Riders    Mirage        16
# 11  2020-03-17               Rooster          Skyfire   Inferno        16
# ...

# %%
# Verificando valores discrepantes
ganhador_mapa = resultados['map_winner']
ganhador_mapa[np.abs(ganhador_mapa) > 2]
# Out:
# Series([], Name: map_winner, dtype: int64)

# %%
# Verificando valores discrepantes
ganhador_mapa = resultados['map_winner']
ganhador_mapa[np.abs(ganhador_mapa) < 0]
# Out:
# Series([], Name: map_winner, dtype: int64)

# %%
# Verificando valores discrepantes
#rounds = resultados['Pontuação como Antiterrorista - Time 1','Pontuação como Terrorista - Time 2','Pontuação como Terrorista - Time 1','Pontuação como Antiterrorista - Time 2']
#rounds[(np.abs(rounds) > 16).any(1)]
new = resultados[['Pontuação como Antiterrorista - Time 1','Pontuação como Terrorista - Time 2','Pontuação como Terrorista - Time 1','Pontuação como Antiterrorista - Time 2']].copy()
#rounds = resultados['Pontuação como Antiterrorista - Time 1']
#rounds
new
# Out:
#        Pontuação como Antiterrorista - Time 1  \
# 0                                           0
# 1                                           8
# 2                                           9
# 3                                           0
# 4                                           4
# ...                                       ...
# 45768                                       8
# 45769                                      10
# 45770                                       7
# 45771                                       4
# 45772                                       4
#
#        Pontuação como Terrorista - Time 2  Pontuação como Terrorista - Time 1  \
# 0                                       1                                   0
# 1                                       6                                   5
# 2                                       6                                   3
# 3                                       8                                   7
# ...

# %%
#vitoria = {0: 'Flawless Victory'}
#resultados['Tipo de vitória'] = resultados['result_1'].map(vitoria)
#resultados['Tipo de vitória'] = resultados['result_2'].map(vitoria)
#resultados.head(5)
pd.options.display.max_rows = 1000

resultados.loc[np.logical_or(np.logical_and(resultados.result_1 == 0, resultados.result_2 > 0), 
                        np.logical_and(resultados.result_2 == 0, resultados.result_1 > 0)), ['Tipo de vitória'] ] = 'Flawless Victory'
#resultados.loc[np.logical_and(resultados.result_1 == 0, resultados.result_2 > 0), ['Tipo de vitória'] ] = 'Flawless Victory'
resultados.head(100)
# Out:
#           date                team_1               team_2      _map  result_1  \
# 0   2020-03-18               Recon 5              TeamOne     Dust2         0
# 1   2020-03-18               Recon 5              TeamOne   Inferno        13
# 2   2020-03-18   New England Whalers             Station7   Inferno        12
# 3   2020-03-18               Rugratz       Bad News Bears   Inferno         7
# 4   2020-03-18               Rugratz       Bad News Bears   Vertigo         8
# 5   2020-03-17           Singularity             Endpoint  Overpass        13
# 6   2020-03-17           Singularity             Endpoint   Vertigo        11
# 7   2020-03-17                Espada              Tricked     Dust2        16
# 8   2020-03-17                Espada              Tricked      Nuke        16
# 9   2020-03-17                fnatic                  BIG    Mirage        12
# 10  2020-03-17                Sprout      Movistar Riders    Mirage        16
# ...

# %%
resultados['Tipo de vitória'] = resultados['Tipo de vitória'].fillna('Victory')
resultados.head(5)
# Out:
#          date               team_1          team_2     _map  result_1  \
# 0  2020-03-18              Recon 5         TeamOne    Dust2         0
# 1  2020-03-18              Recon 5         TeamOne  Inferno        13
# 2  2020-03-18  New England Whalers        Station7  Inferno        12
# 3  2020-03-18              Rugratz  Bad News Bears  Inferno         7
# 4  2020-03-18              Rugratz  Bad News Bears  Vertigo         8
#
#    result_2  map_winner  Time que iniciou como Antiterrorista  \
# 0        16           2                                     2
# 1        16           2                                     2
# 2        16           2                                     1
# 3        16           2                                     2
# 4        16           2                                     2
#
#    Pontuação como Antiterrorista - Time 1  Pontuação como Terrorista - Time 2  \
# 0                                       0                                   1
# ...

# %%
jogos_mibr = resultados.loc[np.logical_or(resultados.team_1 == "MIBR", resultados.team_2 == "MIBR")] 
len(jogos_mibr)
# Out:
# 336

# %%
mibr_vitoria = jogos_mibr.loc[np.logical_or(np.logical_and(resultados.team_1 == "MIBR", resultados.map_winner == 1), np.logical_and(resultados.team_2 == "MIBR", resultados.map_winner == 2))]
len(mibr_vitoria)
# Out:
# 191

# %%
porcentagem_vitoria_mibr = len(mibr_vitoria)/len(jogos_mibr)
porcentagem_vitoria_mibr
# Out:
# 0.5684523809523809

# %%
mibr_astralis = jogos_mibr.loc[np.logical_or(np.logical_and(resultados.team_1 == "MIBR", resultados.team_2 == "Astralis"), np.logical_and(resultados.team_2== "MIBR", resultados.team_1 == "Astralis"))]

# %%
jogos_perfeitos = resultados[resultados['Tipo de vitória'] == 'Flawless Victory']

nomes = []
for index, row in jogos_perfeitos.iterrows():
    if (row['map_winner'] == 2):
        nomes.append(row['team_2'])
    if (row['map_winner'] == 1):
        nomes.append(row['team_1'])
        
    #print(row['rank_1'], row['rank_2'])

# %%
#colunas do dataset que precisamos
colunas = ['player_name','event_name', 'kills', 'assists', 'deaths', 'hs']

#Carregando o data set -> jogadores de CS:Go Professional Matches
jogadores_bruto = pd.read_csv('players.csv', usecols=colunas)

#Exibindo os dez primeiros registros do data set
jogadores_bruto.head(10)
# Out:
#   player_name         event_name  kills  assists  deaths  hs
# 0      Brehze  IEM Katowice 2020     57       14      61  29
# 1        CeRq  IEM Katowice 2020     54       10      54  18
# 2       EliGE  IEM Katowice 2020     55       10      51  28
# 3       Ethan  IEM Katowice 2020     43        5      54  18
# 4         NAF  IEM Katowice 2020     52       22      46  23
# 5    Stewie2K  IEM Katowice 2020     56        8      54  31
# 6     Twistzz  IEM Katowice 2020     72       14      45  45
# 7       nitr0  IEM Katowice 2020     50       15      52  17
# 8   stanislaw  IEM Katowice 2020     44       22      57  17
# 9       tarik  IEM Katowice 2020     50       21      59  18

# %%
ex = jogadores_bruto[np.logical_or(np.logical_or(np.logical_or(np.logical_or(jogadores_bruto['player_name'] == 'coldzera', jogadores_bruto['player_name'] == 'device'), jogadores_bruto['player_name'] == 'FalleN'), jogadores_bruto['player_name'] == 's1mple'), jogadores_bruto['player_name'] == 'olofmeister')]
ex.head()
# Out:
#      player_name         event_name  kills  assists  deaths  hs
# 16      coldzera  IEM Katowice 2020     58       11      52  30
# 17   olofmeister  IEM Katowice 2020     53       10      51  22
# 38        s1mple  IEM Katowice 2020     46       11      20  16
# 369       s1mple  IEM Katowice 2020     70       12      53  20
# 405     coldzera  IEM Katowice 2020     34        5      31  20

# %%
graf = ex.groupby('player_name').sum()
graf
# Out:
#              kills  assists  deaths     hs
# player_name
# FalleN       19725     4574   16782   6023
# coldzera     21228     3696   16198  10318
# device       19345     3378   15287   6422
# olofmeister  15328     3045   14153   7333
# s1mple       17676     2568   13012   7718

# %%
import seaborn as sns
graf.set_index('player_name')


graf

#teste = sns.catplot(x='player_name', y='kills', data=graf, kind='bar', aspect=3)
#teste


#graf.plot.bar()

#axes = graf.plot.bar(rot=0, subplots=True)
#axes[1].legend(loc=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-74040a2bd77a> in <module>
#       1 import seaborn as sns
# ----> 2 graf.set_index('player_name')
#       3
#       4
#       5 graf
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['player_name'] are in the columns"
